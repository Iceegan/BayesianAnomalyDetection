# %% [markdown]
# <a href="https://colab.research.google.com/github/Iceegan/BayesianAnomalyDetection/blob/master/ZoneNData_Overview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this cell on colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/My Drive/')

# %%
# !ls
# Out:
#  0352_001.pdf
# '100% Renewable Petition Signatures.gsheet'
#  161300revT1_19085.pdf
#  2017
# '20181121_VU_BlueSky_Final_Report_DRAFT_v1 for BSAC.docx'
# '20181121_VU_BlueSky_Final_Report_DRAFT_v1 for BSAC.gdoc'
# '2019 Green Fair Registration (1).gdoc'
# '2019 Green Fair Registration.gdoc'
# '2019 Green Fair Registration.pdf'
#  26eba130.568x320r90.mp4
#  31.gdoc
# '4 3 Consent Event Tasks.gsheet'
#  AHT
# 'AHT 2018 Pictures'
#  Algebra_Review
# 'Al Gore Q&A.gform'
# 'Al Gore Q&A (Responses).gsheet'
#  allcombinedPMU1
# 'Analysis of Linear Circuits.pdf'
#  AssignedStrengthsCodes_RAs_2018-2019.xlsx
#  AssignedStrengthsCodes_RAs_2018-2019.xlsx.gsheet
# 'Beyerlein Article.gdoc'
# 'BG Club Forms'
# 'BKBQM Programming'
# 'Black Bear Questions Document.docx'
# 'Black Bear Questions Document.gdoc'
# 'BQBKM Fall 2018 Hall Meeting.gdoc'
# 'BQBKM HRs'
# 'BQBKM Rosters 8.9 (1).gsheet'
# 'BQBKM Rosters 8.9 (2).gsheet'
# 'BQBKM Rosters 8.9 (3).gsheet'
# 'BQBKM Rosters 8.9 (4).gsheet'
# 'BQBKM Rosters 8.9 (5).gsheet'
# 'BQBKM Rosters 8.9.gsheet'
# 'BQBKM Rosters 8.9.xlsx'
# 'BQBKM Staff Information 8.2018.gsheet'
# 'BQBKM Staff Information 8.2018.xlsx'
# 'Branscomb-Blakemore Opening Rosters.xls'
# 'Branscomb-Blakemore Spring Roster 1.3.2020.gsheet'
# 'Branscomb-Blakemore Spring Roster 1.3.2020.xls'
# 'Candidate_Expense_Report_Form (1).gdoc'
#  Candidate_Expense_Report_Form.docx
#  Candidate_Expense_Report_Form.gdoc
# 'Chapter 7 - Religion and Politics.gdoc'
# 'Chemistry 1601 Textbook.pdf'
#  chirps_insectpres.gslides
#  chirps_insectpres.pptx
# 'Circuits Lab 10.gdoc'
#  Classes.gsheet
#  ColabLibraries
# 'Committee Meeting Notes'
# 'Commodore Cash Selection - Print Commodore Card Terms and Conditions.pdf'
# 'Computer Vision Final Project Proposal.gdoc'
# 'ConferenceProposal (1).gdoc'
#  ConferenceProposal.gdoc
#  ConferenceProposal.pdf
# 'Copy of 100% Renewable Petition.gform'
# 'Copy of BQBKM Rosters 8.9.gsheet'
# 'Copy of Branscomb-Blakemore Opening Rosters.xlsx'
# 'Copy of Update 4 23.gslides'
# 'CV Final Project'
#  DeterminingOutliers.pdf
#  directOutput.mat
# 'Discrete Induction Presentatin.gslides'
# 'Discrete Structures Game Solution.gdoc'
# 'DTD Kappas'
#  DTDrive
# 'EECE 3214 Lab 1 Report.gdoc'
# 'Electronics Lab 1.gdoc'
# 'Electronics Lab 2.gdoc'
# 'Electronics Lab 3.gdoc'
# 'Electronics Lab 4.gdoc'
# 'Electronics Lab 5.gdoc'
# 'Electronics lab 6.gdoc'
# 'Electronics Lab 8.gdoc'
# 'Email Response.gdoc'
# 'Email to SPEAR Nominees 2020.gdoc'
# 'ENGM .gslides'
# 'femininity study.docx'
# 'femininity study.gdoc'
# 'FINAL - DADM Future VU Parking Day Flyer Evite 2018.pdf'
# 'Final Gantt v4.gsheet'
# 'Final Gantt v4.xlsx'
#  FineFeels-005.jpg
#  FineFeels-006.jpg
#  FineFeels-009.jpg
#  FineFeels-010.jpg
#  FineFeels-016.jpg
#  fullsizeoutput_17c8.jpeg
#  Gantt_v1.gsheet
#  Gantt_v1.xlsx
# 'GBM 1 Attendance.gsheet'
# 'GBM Attendance 1 6.gsheet'
# 'General Chemistry 1601'
# 'Getting started.pdf'
# 'Greek Presidents.gdoc'
# 'High School Musical Choreography.gslides'
#  Hololens
# 'Hololens Math vs. MergeToNDVI2 .gdoc'
# 'Hololens Project Flow Chart 10 29.gdraw'
# 'Hololens Project Flow Chart.gdraw'
# 'Hololens Project Timeline Goals.gdoc'
#  HW2.docx
# 'IEEE 13 Lines and Loads List.gdoc'
#  IMG_1066.JPG
# 'K&A ASB 2K18'
# 'Keegan Campanelli Resume.pdf'
# 'Keegan Campanelli Sublet Form.gdoc'
# 'Keegan Campanelli Sublet Form.pdf'
# 'Lab 11.gdoc'
# 'Lab 2 notes S&S .gdoc'
# 'Lab 3 Notes.gdoc'
# 'Lab 9.gdoc'
# 'Midnight Munch Budget.gdoc'
# 'Offshore Wind Investment in Virginia.gslides'
# 'Organization Resolution Signatures.gdoc'
#  output
# 'Outstanding Senior Application.gdoc'
# 'pcc document.gdoc'
# 'PHIL 3630 who fuggin cares.gdoc'
# 'POI and Export Integration Instructions.gdoc'
# 'Presentation 1 Tech Comms.gslides'
# 'President SPEAR.gform'
#  profiles
# 'Protection of Minors 101.pdf'
#  Receipts
# 'Renewable Energy Bill (1).docx'
# 'Renewable Energy Bill (1).gdoc'
# 'Renewable Energy Bill (2).gdoc'
# 'Renewable Energy Bill.docx'
# 'Renewable Energy Bill.gdoc'
# 'Renewable Energy Petition Language.gdoc'
#  Results.zip
# 'ROAD Attendance.xlsx'
# 'ROAD Attendance.xlsx.gsheet'
# 'Road Chair Application.gdoc'
#  Rush
# 'Senior Design'
# 'Senior Design 6_27'
# 'Senior Design 6_9.drawio'
# 'Senior Design 7_9'
# 'Sig Challenge Pics'
# 'Sig Challenge Pics (2)'
# 'Simulation Design Overview.gdoc'
# 'Smart Cities Project'
# 'Sociology of Religion Midterm'
#  SPEAR
# 'SPEAR Board 2020-2021 Application.gform'
# 'SPEAR Branscomb Earth Day Event.gsheet'
# 'SPEAR Nominations 2020.gsheet'
# 'SPEAR Notes'
# 'SPEAR Platforms.gdoc'
# 'SPEAR trifold.docx'
# 'SPEAR trifold.gdoc'
# 'SPEAR trifold.pdf'
# 'Spring 2019 Evaluation Keegan.gdoc'
# 'Spring 2019 Evaluation Template.docx'
# 'Spring 2019 Evaluation Template.gdoc'
# 'Student Handout to Complete Expense Report in Oracle Cloud  FINAL  1-22-.._.gdoc'
# 'Sustainability Advisory Council Overview DRAFT 11.13.19.docx'
# 'Sustainability Advisory Council Overview DRAFT 11.13.19.gdoc'
# 'Sustainability Steering Committee Proposal.docx'
# 'Sustainability Steering Committee Proposal.gdoc'
# 'Tech Comms Presentation.gslides'
# 'Test Bank'
#  Textbooks
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
# 'Verdigris Talking Notes.gdoc'
#  VID_20161021_150558.mp4
# 'Wind Turbine Project'
#  ZoneNData
#  ZoneNData.zip

# %%
# !sudo apt-get install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 25 not upgraded.

# %%
# !unzip Results.zip -d ExtractedZoneN
# Out:
# Archive:  Results.zip
#    creating: ExtractedZoneN/Results/B7Grounding_abcFault/
#   inflating: ExtractedZoneN/Results/B7Grounding_abcFault/buses.csv
#   inflating: ExtractedZoneN/Results/B7Grounding_abcFault/freq.csv
#   inflating: ExtractedZoneN/Results/B7Grounding_abcFault/lines.csv
#    creating: ExtractedZoneN/Results/L59Grounding_abfault/
#   inflating: ExtractedZoneN/Results/L59Grounding_abfault/buses.csv
#   inflating: ExtractedZoneN/Results/L59Grounding_abfault/freq.csv
#   inflating: ExtractedZoneN/Results/L59Grounding_abfault/lines.csv
#    creating: ExtractedZoneN/Results/L59LineOpen_abcFault/
#   inflating: ExtractedZoneN/Results/L59LineOpen_abcFault/buses.csv
#   inflating: ExtractedZoneN/Results/L59LineOpen_abcFault/freq.csv
#   inflating: ExtractedZoneN/Results/L59LineOpen_abcFault/lines.csv
#    creating: ExtractedZoneN/Results/MachineLossM1_abc/
#   inflating: ExtractedZoneN/Results/MachineLossM1_abc/buses.csv
#   inflating: ExtractedZoneN/Results/MachineLossM1_abc/freq.csv
#   inflating: ExtractedZoneN/Results/MachineLossM1_abc/lines.csv

# %%
# !ls
# Out:
#  0352_001.pdf
# '100% Renewable Petition Signatures.gsheet'
#  161300revT1_19085.pdf
#  2017
# '20181121_VU_BlueSky_Final_Report_DRAFT_v1 for BSAC.docx'
# '20181121_VU_BlueSky_Final_Report_DRAFT_v1 for BSAC.gdoc'
# '2019 Green Fair Registration (1).gdoc'
# '2019 Green Fair Registration.gdoc'
# '2019 Green Fair Registration.pdf'
#  26eba130.568x320r90.mp4
#  31.gdoc
# '4 3 Consent Event Tasks.gsheet'
#  AHT
# 'AHT 2018 Pictures'
#  Algebra_Review
# 'Al Gore Q&A.gform'
# 'Al Gore Q&A (Responses).gsheet'
#  allcombinedPMU1
# 'Analysis of Linear Circuits.pdf'
#  AssignedStrengthsCodes_RAs_2018-2019.xlsx
#  AssignedStrengthsCodes_RAs_2018-2019.xlsx.gsheet
# 'Beyerlein Article.gdoc'
# 'BG Club Forms'
# 'BKBQM Programming'
# 'Black Bear Questions Document.docx'
# 'Black Bear Questions Document.gdoc'
# 'BQBKM Fall 2018 Hall Meeting.gdoc'
# 'BQBKM HRs'
# 'BQBKM Rosters 8.9 (1).gsheet'
# 'BQBKM Rosters 8.9 (2).gsheet'
# 'BQBKM Rosters 8.9 (3).gsheet'
# 'BQBKM Rosters 8.9 (4).gsheet'
# 'BQBKM Rosters 8.9 (5).gsheet'
# 'BQBKM Rosters 8.9.gsheet'
# 'BQBKM Rosters 8.9.xlsx'
# 'BQBKM Staff Information 8.2018.gsheet'
# 'BQBKM Staff Information 8.2018.xlsx'
# 'Branscomb-Blakemore Opening Rosters.xls'
# 'Branscomb-Blakemore Spring Roster 1.3.2020.gsheet'
# 'Branscomb-Blakemore Spring Roster 1.3.2020.xls'
# 'Candidate_Expense_Report_Form (1).gdoc'
#  Candidate_Expense_Report_Form.docx
#  Candidate_Expense_Report_Form.gdoc
# 'Chapter 7 - Religion and Politics.gdoc'
# 'Chemistry 1601 Textbook.pdf'
#  chirps_insectpres.gslides
#  chirps_insectpres.pptx
# 'Circuits Lab 10.gdoc'
#  Classes.gsheet
#  ColabLibraries
# 'Committee Meeting Notes'
# 'Commodore Cash Selection - Print Commodore Card Terms and Conditions.pdf'
# 'Computer Vision Final Project Proposal.gdoc'
# 'ConferenceProposal (1).gdoc'
#  ConferenceProposal.gdoc
#  ConferenceProposal.pdf
# 'Copy of 100% Renewable Petition.gform'
# 'Copy of BQBKM Rosters 8.9.gsheet'
# 'Copy of Branscomb-Blakemore Opening Rosters.xlsx'
# 'Copy of Update 4 23.gslides'
# 'CV Final Project'
#  DeterminingOutliers.pdf
#  directOutput.mat
# 'Discrete Induction Presentatin.gslides'
# 'Discrete Structures Game Solution.gdoc'
# 'DTD Kappas'
#  DTDrive
# 'EECE 3214 Lab 1 Report.gdoc'
# 'Electronics Lab 1.gdoc'
# 'Electronics Lab 2.gdoc'
# 'Electronics Lab 3.gdoc'
# 'Electronics Lab 4.gdoc'
# 'Electronics Lab 5.gdoc'
# 'Electronics lab 6.gdoc'
# 'Electronics Lab 8.gdoc'
# 'Email Response.gdoc'
# 'Email to SPEAR Nominees 2020.gdoc'
# 'ENGM .gslides'
#  ExtractedZoneN
# 'femininity study.docx'
# 'femininity study.gdoc'
# 'FINAL - DADM Future VU Parking Day Flyer Evite 2018.pdf'
# 'Final Gantt v4.gsheet'
# 'Final Gantt v4.xlsx'
#  FineFeels-005.jpg
#  FineFeels-006.jpg
#  FineFeels-009.jpg
#  FineFeels-010.jpg
#  FineFeels-016.jpg
#  fullsizeoutput_17c8.jpeg
#  Gantt_v1.gsheet
#  Gantt_v1.xlsx
# 'GBM 1 Attendance.gsheet'
# 'GBM Attendance 1 6.gsheet'
# 'General Chemistry 1601'
# 'Getting started.pdf'
# 'Greek Presidents.gdoc'
# 'High School Musical Choreography.gslides'
#  Hololens
# 'Hololens Math vs. MergeToNDVI2 .gdoc'
# 'Hololens Project Flow Chart 10 29.gdraw'
# 'Hololens Project Flow Chart.gdraw'
# 'Hololens Project Timeline Goals.gdoc'
#  HW2.docx
# 'IEEE 13 Lines and Loads List.gdoc'
#  IMG_1066.JPG
# 'K&A ASB 2K18'
# 'Keegan Campanelli Resume.pdf'
# 'Keegan Campanelli Sublet Form.gdoc'
# 'Keegan Campanelli Sublet Form.pdf'
# 'Lab 11.gdoc'
# 'Lab 2 notes S&S .gdoc'
# 'Lab 3 Notes.gdoc'
# 'Lab 9.gdoc'
# 'Midnight Munch Budget.gdoc'
# 'Offshore Wind Investment in Virginia.gslides'
# 'Organization Resolution Signatures.gdoc'
#  output
# 'Outstanding Senior Application.gdoc'
# 'pcc document.gdoc'
# 'PHIL 3630 who fuggin cares.gdoc'
# 'POI and Export Integration Instructions.gdoc'
# 'Presentation 1 Tech Comms.gslides'
# 'President SPEAR.gform'
#  profiles
# 'Protection of Minors 101.pdf'
#  Receipts
# 'Renewable Energy Bill (1).docx'
# 'Renewable Energy Bill (1).gdoc'
# 'Renewable Energy Bill (2).gdoc'
# 'Renewable Energy Bill.docx'
# 'Renewable Energy Bill.gdoc'
# 'Renewable Energy Petition Language.gdoc'
#  Results.zip
# 'ROAD Attendance.xlsx'
# 'ROAD Attendance.xlsx.gsheet'
# 'Road Chair Application.gdoc'
#  Rush
# 'Senior Design'
# 'Senior Design 6_27'
# 'Senior Design 6_9.drawio'
# 'Senior Design 7_9'
# 'Sig Challenge Pics'
# 'Sig Challenge Pics (2)'
# 'Simulation Design Overview.gdoc'
# 'Smart Cities Project'
# 'Sociology of Religion Midterm'
#  SPEAR
# 'SPEAR Board 2020-2021 Application.gform'
# 'SPEAR Branscomb Earth Day Event.gsheet'
# 'SPEAR Nominations 2020.gsheet'
# 'SPEAR Notes'
# 'SPEAR Platforms.gdoc'
# 'SPEAR trifold.docx'
# 'SPEAR trifold.gdoc'
# 'SPEAR trifold.pdf'
# 'Spring 2019 Evaluation Keegan.gdoc'
# 'Spring 2019 Evaluation Template.docx'
# 'Spring 2019 Evaluation Template.gdoc'
# 'Student Handout to Complete Expense Report in Oracle Cloud  FINAL  1-22-.._.gdoc'
# 'Sustainability Advisory Council Overview DRAFT 11.13.19.docx'
# 'Sustainability Advisory Council Overview DRAFT 11.13.19.gdoc'
# 'Sustainability Steering Committee Proposal.docx'
# 'Sustainability Steering Committee Proposal.gdoc'
# 'Tech Comms Presentation.gslides'
# 'Test Bank'
#  Textbooks
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet.gsheet'
# 'Verdigris Talking Notes.gdoc'
#  VID_20161021_150558.mp4
# 'Wind Turbine Project'
#  ZoneNData.zip

# %%
os.chdir('ExtractedZoneN/Results/B7Grounding_abcFault')

# %%
import pandas as pd
pd.read_csv('buses.csv')
# Out:
#           time  B1VA_Mag  B1VB_Mag  ...   B10IA_Ang  B10IB_Ang   B10IC_Ang
# 0       0.0000  0.000000  0.000000  ...    0.000000   0.000000    0.000000
# 1       0.0004  0.000000  0.000000  ...    0.000000   0.000000    0.000000
# 2       0.0008  0.000000  0.000000  ...    0.000000   0.000000    0.000000
# 3       0.0012  0.000000  0.000000  ...    0.000000   0.000000    0.000000
# 4       0.0016  0.000000  0.000000  ...    0.000000   0.000000    0.000000
# ...        ...       ...       ...  ...         ...        ...         ...
# 49995  19.9980  1.056499  1.056504  ...  128.395004   8.395973 -111.606533
# 49996  19.9984  1.056492  1.056519  ...  128.395006   8.395236 -111.607057
# 49997  19.9988  1.056488  1.056535  ...  128.394952   8.394423 -111.607449
# 49998  19.9992  1.056488  1.056550  ...  128.394809   8.393572 -111.607712
# 49999  19.9996  1.056492  1.056563  ...  128.394553   8.392720 -111.607860
#
# [50000 rows x 121 columns]
